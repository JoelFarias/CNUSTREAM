# %% [markdown]
# ## 0.Fase inicial
# Importando bibliotecas, e leituras da bases

# %%
import geopandas as gpd # Leitura de arquivos shapefile

quilombola = gpd.read_file("areas-PA/Áreas de Quilombolas_PA/Áreas de Quilombolas_PA.shp") # Áreas quilombolas do Pará
quilombola.head()
# Out:
#    cd_quilomb  cd_sr            nr_process  \
# 0         NaN  SR-01  54113.000248/2005-45
# 1         NaN  SR-01           1999/208353
# 2         NaN  SR-30  54501.001765/2014-59
# 3         NaN  SR-01            2006/14848
# 4         NaN  SR-01           2005/385246
#
#                             nm_comunid          nm_municip cd_uf  dt_publica  \
# 0  SAO MIGUEL ARCANJO DE NOVA LUDICEIA             IRITUIA    PA  04/09/2018
# 1                            CAMIRANGA  CACHOEIRA DO PIRIA    PA        None
# 2                   ALTO TROMBETAS  II           ORIXIMINÁ    PA  15/02/2017
# 3                               MATIAS              CAMETA    PA        None
# 4                 RIBEIRA DO JAMBU-AÇU                MOJU    PA        None
#
#    dt_public1  nr_familia  dt_titulac  ...  st_titulad  dt_decreto tp_levanta  \
# 0        None       305.0        None  ...        None        None       None
# 1        None        39.0  16/11/2002  ...        None        None       None
# 2  19/07/2018       243.0        None  ...        None        None        GPS
# 3        None        45.0  13/05/2008  ...        None        None       None
# 4        None        62.0  02/12/2008  ...        None        None       None
#
#   nr_escalao   area_calc_    perimetro_    esfera      fase  responsave  \
# 0       None     178.6983  9.484942e+04      None      RTID       INCRA
# 1       None     330.1785  6.568506e+04  ESTADUAL  TITULADO      ITERPA
# 2   1:20.000  293586.7725  5.196123e+06   FEDERAL  PORTARIA       INCRA
# 3       None    1447.4652  1.429758e+05  ESTADUAL  TITULADO      ITERPA
# 4       None    1309.9099  1.335416e+05  ESTADUAL  TITULADO      ITERPA
#
#                                             geometry
# 0  POLYGON ((-47.39758 -1.67592, -47.40063 -1.676...
# 1  POLYGON ((-46.26632 -1.81096, -46.28319 -1.817...
# 2  MULTIPOLYGON (((-56.4222 -1.57448, -56.42239 -...
# 3  POLYGON ((-49.59596 -2.32475, -49.59597 -2.326...
# 4  POLYGON ((-48.46293 -1.78019, -48.4711 -1.7805...
#
# [5 rows x 24 columns]

# %%
cnuc = gpd.read_file("Brasil/shp_cnuc_2024_10/shp_cnuc_2024_10_pol.shp", encoding="utf8") # Áreas das Unidade de conservação, necessário o encoding para leitura correta
cnuc.head()
# Out:
#   gml_id uc_id       cd_cnuc   wdpa_pid  \
# 0   None     2  0000.00.0002      31755
# 1   None     4  0000.00.0004  555783601
# 2   None     6  0000.00.0006     351716
# 3   None    11  0000.00.0011  555600306
# 4   None    12  0000.00.0012      31758
#
#                                              nome_uc    cria_ano  \
# 0     ÁREA DE PROTEÇÃO AMBIENTAL CAVERNAS DO PERUAÇU  28-09-1989
# 1  ÁREA DE PROTEÇÃO AMBIENTAL DA BACIA DO RIO SÃO...  07-11-1983
# 2        ÁREA DE PROTEÇÃO AMBIENTAL DA BALEIA FRANCA  14-09-2000
# 3    ÁREA DE PROTEÇÃO AMBIENTAL SERRA DA MANTIQUEIRA  06-06-1985
# 4      ÁREA DE PROTEÇÃO AMBIENTAL SERRA DA TABATINGA  16-07-2002
#
#                        cria_ato                          outro_ato  \
# 0   Decreto 98182 de 26-09-1989                     Sem informação
# 1   Decreto 88940 de 07-11-1983                     Sem informação
# 2      Decreto SN de 14-09-2000                     Sem informação
# 3   Decreto 91304 de 03-06-1985                     Sem informação
# 4  Decreto 99.278 de 06-06-1990  Decreto S/N de 16-07-2002 Redução
#
#         pl_manejo       co_gestor  ... amazonia  caatinga    cerrado  \
# 0  Sem informação             Sim  ...     None  26660.87  116692.42
# 1  Sem informação  Sem informação  ...     None      None   82679.26
# 2  Sem informação             Sim  ...     None      None       None
# 3             Sim             Sim  ...     None      None       None
# 4  Sem informação  Sem informação  ...     None      None   76964.58
#
#   matlantica pampa pantanal    marinho situacao limite  \
# 0       None  None     None       None    Ativo     uc
# 1       None  None     None       None    Ativo     uc
# 2    34957.2  None     None  119934.73    Ativo     uc
# 3   437517.1  None     None       None    Ativo     uc
# 4       None  None     None       None    Ativo     uc
#
#                                             geometry
# 0  POLYGON ((-44.67888 -14.83892, -44.67818 -14.8...
# 1  MULTIPOLYGON (((-47.505 -15.58143, -47.5051 -1...
# 2  POLYGON ((-48.47895 -27.76973, -48.47887 -27.7...
# 3  POLYGON ((-44.75234 -21.92471, -44.7527 -21.92...
# 4  POLYGON ((-45.69822 -10.26292, -45.71057 -10.2...
#
# [5 rows x 31 columns]

# %%
sigef = gpd.read_file("areas-PA/AREA_IMOVEL/AREA_IMOVEL_1.shp") # Áreas de imóveis rurais / CAR
sigef.head()
# Out:
#       cod_tema        nom_tema                                   cod_imovel  \
# 0  AREA_IMOVEL  Area do Imovel  PA-1500503-1B415D59863B470E9EFB4BE2F150E6D7
# 1  AREA_IMOVEL  Area do Imovel  PA-1500958-D1D6D17578FD40CEA06B42C266271E43
# 2  AREA_IMOVEL  Area do Imovel  PA-1501451-2DE323F56317468CB81C6729908F9A2B
# 3  AREA_IMOVEL  Area do Imovel  PA-1502806-0F9E06018BB84F64B36348E6DE99F3AE
# 4  AREA_IMOVEL  Area do Imovel  PA-1506807-5192E004BC54471C814813F0A396613C
#
#    mod_fiscal     num_area ind_status ind_tipo          des_condic  \
# 0  12992.3066  909461.4607         PE      IRU  Aguardando analise
# 1      0.3736    4068.0561         AT      AST  Aguardando analise
# 2      4.0000  530798.6783         AT      PCT  Aguardando analise
# 3      0.0286     370.6387         AT      AST  Aguardando analise
# 4      4.0000  677232.0650         AT      PCT  Aguardando analise
#
#         municipio cod_estado  dat_criaca  dat_atuali  \
# 0        Almeirim         PA  22/06/2016  03/11/2017
# 1  Aurora do Para         PA  02/05/2018  02/05/2018
# 2        Belterra         PA  09/02/2018  09/02/2018
# 3      Curralinho         PA  04/05/2018  04/05/2018
# 4        Santarem         PA  20/07/2018  20/07/2018
#
#                                             geometry
# 0  POLYGON ((-52.76075 -0.49125, -52.75898 -0.491...
# 1  POLYGON ((-47.72608 -2.04675, -47.72384 -2.046...
# 2  POLYGON ((-54.89625 -2.75134, -54.8971 -2.8506...
# 3  POLYGON ((-49.711 -1.66205, -49.711 -1.66205, ...
# 4  POLYGON ((-55.02526 -2.34586, -55.02657 -2.347...

# %%
tis = gpd.read_file("Brasil/tis_poligonais/tis_poligonais.shp") # Terras indígenas
tis.head()
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:196: RuntimeWarning: Brasil/tis_poligonais/tis_poligonais.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#    gid  terrai_cod              terrai_nom               etnia_nome  \
# 0    1         101         Acapuri de Cima                   Kokama
# 1    2         201                   Acimã                  Apurinã
# 2   57         601                   Aconã              Tingui-Botó
# 3  494       73806  Aldeia Escola Floresta                 Maxakali
# 4  469       73793         Aldeia Katurama  Pataxó, Pataxo Há-Há-Há
#
#              municipio_ uf_sigla  superficie       fase_ti  \
# 0             Fonte Boa       AM  18393.9411  Regularizada
# 1                Lábrea       AM  40686.0340  Regularizada
# 2                Traipu       AL    267.7862  Regularizada
# 3         Teófilo Otoni       MG    121.0000  Regularizada
# 4  São Joaquim de Bicas       MG    346.1240  Regularizada
#
#                  modalidade reestudo_t  \
# 0  Tradicionalmente ocupada       None
# 1  Tradicionalmente ocupada       None
# 2          Reserva Indígena       None
# 3          Reserva Indígena       None
# 4         Dominial Indígena       None
#
#                                                   cr faixa_fron    undadm_cod  \
# 0              COORDENACAO REGIONAL DO ALTO SOLIMOES        Não  3.020200e+10
# 1                   COORDENACAO REGIONAL MÉDIO PURUS        Não  3.020200e+10
# 2                    COORDENACAO REGIONAL NORDESTE I        Não  3.020200e+10
# 3  COORDENACAO REGIONAL DE MINAS GERAIS E ESPIRIT...        Não  3.020200e+10
# 4  COORDENACAO REGIONAL DE MINAS GERAIS E ESPIRIT...        Não  3.020200e+10
#
#                                           undadm_nom undadm_sig dominio_un  \
# 0              COORDENACAO REGIONAL DO ALTO SOLIMOES      CR-AS          t
# 1                   COORDENACAO REGIONAL MÉDIO PURUS    CR-Mpur          t
# 2                    COORDENACAO REGIONAL NORDESTE I    CR-NE-I          t
# 3  COORDENACAO REGIONAL DE MINAS GERAIS E ESPIRIT...    CR-MGES          t
# 4  COORDENACAO REGIONAL DE MINAS GERAIS E ESPIRIT...    CR-MGES          t
#
#    data_atual  epsg                                           geometry
# 0  05/09/2023     0  POLYGON ((-66.88359 -2.53752, -66.87457 -2.537...
# 1        None     0  POLYGON ((-66.30929 -7.79995, -66.30929 -7.799...
# 2        None     0  POLYGON ((-36.94514 -10.07113, -36.94377 -10.0...
# 3  02/08/2024     0  POLYGON ((-41.39557 -17.89386, -41.39488 -17.8...
# 4  14/04/2023     0  POLYGON ((-44.23058 -20.05617, -44.23078 -20.0...

# %%
# !wget https://storage.googleapis.com/alerta-public/dashboard/downloads/dashboard_alerts-shapefile.zip

# %%
# !unzip /content/dashboard_alerts-shapefile.zip

# %%
alertas = gpd.read_file("Brasil/dashboard_alerts-shapefile/alerts-shapefile.shp")
# alertas = gpd.read_file('/content/dashboard_alerts-shapefile.shp')
alertas.head()
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:196: RuntimeWarning: Brasil/dashboard_alerts-shapefile/alerts-shapefile.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#    CODEALERTA                       FONTE     BIOMA       ESTADO  \
# 0       53758  {DETERB-AMAZONIA,GLAD,SAD}  Amazônia     AMAZONAS
# 1      576502                       {SAD}  Amazônia     AMAZONAS
# 2      592239                       {SAD}  Amazônia  MATO GROSSO
# 3      578822                       {SAD}  Amazônia     AMAZONAS
# 4      594084             {DETER-CERRADO}   Cerrado  MATO GROSSO
#
#                MUNICIPIO  AREAHA  ANODETEC  DATADETEC   DTIMGANT   DTIMGDEP  \
# 0                Humaitá    0.32    2019.0 2019-09-01 2019-05-28 2019-11-09
# 1                 Lábrea    7.38    2022.0 2022-05-01 2021-07-30 2022-07-03
# 2  São José do Rio Claro   48.26    2022.0 2022-04-01 2021-12-27 2022-05-31
# 3                Humaitá  125.07    2022.0 2022-05-01 2021-07-30 2022-07-07
# 4          Rosário Oeste  764.28    2022.0 2022-04-26 2021-05-29 2022-05-28
#
#      DTPUBLI     VPRESSAO                                           geometry
# 0 2020-02-11  agriculture  MULTIPOLYGON (((-63.28165 -7.22014, -63.28165 ...
# 1 2022-06-30  agriculture  POLYGON ((-64.69531 -7.50426, -64.6952 -7.5042...
# 2 2022-07-06  agriculture  MULTIPOLYGON (((-56.82125 -13.7104, -56.82192 ...
# 3 2022-06-30  agriculture  MULTIPOLYGON (((-63.38318 -7.60079, -63.38312 ...
# 4 2022-07-06  agriculture  MULTIPOLYGON (((-56.95738 -15.43974, -56.95727...

# %% [markdown]
# ## 1.Tratamento dos dados
# Seleção, limpeza e transformação dos dados

# %%
# Remover acentos dos nomes dos municípios, algumas bases não vieram com acentos nos nomes, ou com nomes errados
import unidecode

def remover_acentos(texto):
    return unidecode.unidecode(texto)

# %% [markdown]
# ### 1.1 Quilombolas

# %%
quilombola_f = quilombola.loc[:, ["nm_comunid", "nm_municip", "nr_familia", "nr_area_ha", "geometry"]] # Selecionando algumas colunas
quilombola_f.head()
# Out:
#                             nm_comunid          nm_municip  nr_familia  \
# 0  SAO MIGUEL ARCANJO DE NOVA LUDICEIA             IRITUIA       305.0
# 1                            CAMIRANGA  CACHOEIRA DO PIRIA        39.0
# 2                   ALTO TROMBETAS  II           ORIXIMINÁ       243.0
# 3                               MATIAS              CAMETA        45.0
# 4                 RIBEIRA DO JAMBU-AÇU                MOJU        62.0
#
#     nr_area_ha                                           geometry
# 0    4334.5838  POLYGON ((-47.39758 -1.67592, -47.40063 -1.676...
# 1     320.6121  POLYGON ((-46.26632 -1.81096, -46.28319 -1.817...
# 2  103871.2778  MULTIPOLYGON (((-56.4222 -1.57448, -56.42239 -...
# 3    1424.6701  POLYGON ((-49.59596 -2.32475, -49.59597 -2.326...
# 4   13003.5089  POLYGON ((-48.46293 -1.78019, -48.4711 -1.7805...

# %%
quilombola_f.reset_index(drop=True, inplace=True) # Resetando o índice para facilitar depois
quilombola_f["nm_municip"] = quilombola_f["nm_municip"].str.lower() # Colocando o nome dos municípios em minúsculo
quilombola_f["nm_municip"] = quilombola_f["nm_municip"].apply(remover_acentos) # Removendo acentos

quilombola_f.sample(5)
# Out:
#                                    nm_comunid nm_municip  nr_familia  \
# 82                               CACAU E OVOS    colares         NaN
# 22      CENTRO OURO, NOSSA SENHORA DAS GRACAS       moju       123.0
# 37  GURUPA MIRIM, JOCOJO, FLEXINHA, CARRAZEDO     gurupa       300.0
# 31                  SANTA MARIA DO TRAQUATEUA       moju        27.0
# 48                              SAO SEBASTIAO       moju        39.0
#
#     nr_area_ha                                           geometry
# 82         NaN  POLYGON ((-48.19431 -0.81978, -48.19346 -0.820...
# 22   5243.1409  POLYGON ((-48.54208 -1.88247, -48.54216 -1.904...
# 37  83437.1287  POLYGON ((-51.64838 -1.46381, -51.65211 -1.48,...
# 31   1163.6383  POLYGON ((-48.50857 -1.94575, -48.50978 -1.950...
# 48    962.0094  POLYGON ((-48.52677 -1.94976, -48.52708 -1.955...

# %% [markdown]
# ### 1.2 CNUC

# %%
cnuc_f = cnuc[cnuc.uf.str.contains("PARÁ")] # Filtrando apenas as UCs do Pará
cnuc_f.reset_index(drop=True, inplace=True) # Resetando o índice para facilitar depois
cnuc_f["municipio"] = cnuc_f["municipio"].str.lower() # Colocando o nome dos municípios em minúsculo
cnuc_f["municipio"] = cnuc_f["municipio"].apply(remover_acentos) # Removendo acentos
cnuc_f["municipio"] = cnuc_f["municipio"].str.replace("(pa)", '') # Removendo a sigla do estado para que os municípios fiquem com nomes iguais
cnuc_f = cnuc_f[["nome_uc", "ha_total", "uf", "municipio", "situacao", "geometry"]] # Selecionando algumas colunas

cnuc_f.sample(5)
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                               nome_uc   ha_total    uf  \
# 27  ÁREA DE PROTEÇÃO AMBIENTAL DA REGIÃO METROLPOL...    5646.57  PARÁ
# 14                        PARQUE NACIONAL DO RIO NOVO  538108.45  PARÁ
# 77         RESERVA EXTRATIVISTA TERRA GRANDE-PRACUÚBA  194855.83  PARÁ
# 59                  ÁREA DE PROTEÇÃO AMBIENTAL DO JUÁ     126.35  PARÁ
# 11            RESERVA EXTRATIVISTA MARINHA TRACUATEUA    27864.3  PARÁ
#
#                                    municipio situacao  \
# 27                       ananindeua , belem     Ativo
# 14                itaituba , novo progresso     Ativo
# 77  curralinho , sao sebastiao da boa vista     Ativo
# 59                                 santarem     Ativo
# 11                               tracuateua     Ativo
#
#                                              geometry
# 27  POLYGON ((-48.40276 -1.38493, -48.40291 -1.385...
# 14  POLYGON ((-56.90313 -7.27737, -56.90226 -7.278...
# 77  POLYGON ((-50.24261 -1.37674, -50.24802 -1.360...
# 59  POLYGON ((-54.78672 -2.44561, -54.78868 -2.444...
# 11  POLYGON ((-46.79568 -0.82377, -46.79522 -0.824...

# %% [markdown]
# ### 1.3 SIGEF

# %%
sigef_f = sigef[sigef["ind_tipo"] != "PCT"] # Filtrando para retirar CARs do tipo Território Tradicional de Povos e Comunidades Tradicionais. Estes PCTs são terras indígenas, quilombolas, etc.
sigef_f.reset_index(drop=True, inplace=True) # Resetando o índice para facilitar depois
sigef_f = sigef_f.loc[:, ["cod_imovel", "ind_tipo", "municipio", "num_area", "geometry"]] # Selecionando algumas colunas
sigef_f["municipio"] = sigef_f["municipio"].str.lower() # Colocando o nome dos municípios em minúsculo
sigef_f["municipio"] = sigef_f["municipio"].apply(remover_acentos) # Removendo acentos
sigef_f.head()
# Out:
#                                     cod_imovel ind_tipo            municipio  \
# 0  PA-1500503-1B415D59863B470E9EFB4BE2F150E6D7      IRU             almeirim
# 1  PA-1500958-D1D6D17578FD40CEA06B42C266271E43      AST       aurora do para
# 2  PA-1502806-0F9E06018BB84F64B36348E6DE99F3AE      AST           curralinho
# 3  PA-1507607-EA2B29DB07714B218775479DCEFBC906      IRU  sao miguel do guama
# 4  PA-1506708-459EEBF6FB804F738EA5FF9F4786FAED      IRU  santana do araguaia
#
#       num_area                                           geometry
# 0  909461.4607  POLYGON ((-52.76075 -0.49125, -52.75898 -0.491...
# 1    4068.0561  POLYGON ((-47.72608 -2.04675, -47.72384 -2.046...
# 2     370.6387  POLYGON ((-49.711 -1.66205, -49.711 -1.66205, ...
# 3      13.9904  POLYGON ((-47.63481 -1.55772, -47.63301 -1.557...
# 4     248.4772  POLYGON ((-50.65017 -8.92169, -50.6525 -8.9327...

# %% [markdown]
# ### 1.4 TIS

# %%
tis_f = tis[tis["uf_sigla"] == "PA"] # Filtrando pelo estado do Pará
tis_f.reset_index(drop=True, inplace=True) # Resetando o índice para facilitar depois
tis_f["municipio"] = tis_f["municipio_"].str.lower() # Colocando o nome dos municípios em minúsculo
tis_f["municipio"] = tis_f["municipio"].apply(remover_acentos) # Removendo acentos
tis_f = tis_f.loc[:, ["etnia_nome", "municipio", "geometry"]] # Selecionando algumas colunas

tis_f.sample(5)
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#         etnia_nome                                     municipio  \
# 49  Xipáya,Kuruáya                                      altamira
# 38       Mundurukú                              itaituba,trairao
# 46           Tembé                                      tome-acu
# 30           Yudjá  vitoria do xingu,anapu,senador jose porfirio
# 14       Guajajara                                    itupiranga
#
#                                              geometry
# 49  MULTIPOLYGON (((-54.46133 -5.34588, -54.46143 ...
# 38  MULTIPOLYGON (((-56.26021 -4.46682, -56.25869 ...
# 46  POLYGON ((-48.3524 -2.26825, -48.35238 -2.2687...
# 30  POLYGON ((-51.72996 -3.35211, -51.72969 -3.352...
# 14  POLYGON ((-49.9706 -4.89988, -49.97012 -4.9000...

# %% [markdown]
# ### 1.5 Alertas

# %%
alertas_f = alertas[alertas["ESTADO"] == "PARÁ"] # Filtrando pelo estado do Pará
alertas_f.reset_index(drop=True, inplace=True) # Resetando o índice para facilitar depois
alertas_f["MUNICIPIO"] = alertas_f["MUNICIPIO"].str.lower() # Colocando o nome dos municípios em minúsculo
alertas_f["MUNICIPIO"] = alertas_f["MUNICIPIO"].apply(remover_acentos) # Removendo acentos

alertas_f.sample(5)
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#        CODEALERTA                  FONTE     BIOMA ESTADO          MUNICIPIO  \
# 9134       730888                  {SAD}  Amazônia   PARÁ  novo repartimento
# 33613      238777                  {SAD}  Amazônia   PARÁ             obidos
# 58805      221330                  {SAD}  Amazônia   PARÁ             portel
# 46744      397359  {DETERB-AMAZONIA,SAD}  Amazônia   PARÁ              anapu
# 71865      340912                  {SAD}  Amazônia   PARÁ             uruara
#
#        AREAHA  ANODETEC  DATADETEC   DTIMGANT   DTIMGDEP    DTPUBLI  \
# 9134    19.62    2022.0 2022-10-01 2021-08-19 2023-01-20 2022-11-28
# 33613    1.05    2020.0 2020-10-01 2020-08-31 2020-11-01 2020-11-23
# 58805    2.78    2020.0 2020-09-01 2020-08-27 2020-12-10 2020-10-22
# 46744   73.05    2021.0 2021-07-01 2021-06-14 2021-09-20 2021-08-21
# 71865   25.10    2021.0 2021-05-01 2020-10-29 2021-05-27 2021-06-16
#
#           VPRESSAO                                           geometry
# 9134   agriculture  POLYGON ((-50.57497 -4.79035, -50.57527 -4.790...
# 33613  agriculture  POLYGON ((-55.22373 -1.62526, -55.22333 -1.624...
# 58805  agriculture  POLYGON ((-50.59473 -2.18096, -50.59508 -2.180...
# 46744  agriculture  POLYGON ((-51.54901 -3.00069, -51.54887 -3.001...
# 71865  agriculture  MULTIPOLYGON (((-53.91054 -3.93971, -53.91033 ...

# %%
alertas_f.shape # Verificando os valores únicos da coluna de pressão
# Out:
# (109488, 13)

# %% [markdown]
# ## 2. Explorando as áreas

# %%
# Listar todos os municípios presentes nas bases para filtrar a base da SIGEF
def listar_mun(column, sep):  
    muns = set()
    for i in column.__iter__():
        if i.find(sep) != -1:
            i = i.split(sep)
            for j in i:
                muns.add(j)
        else:
            muns.add(i)
    return muns

# %%
municipios_quilombolas = listar_mun(quilombola_f["nm_municip"], ' / ')
print(len(municipios_quilombolas))
# Out:
# 38

# %%
municipios_cnuc = listar_mun(cnuc_f["municipio"], ' , ')
print(len(municipios_cnuc))
# Out:
# 95

# %%
municipios_tis = listar_mun(tis_f["municipio"], ',')
print(len(municipios_tis))
# Out:
# 47

# %%
municipios = municipios_quilombolas.union(municipios_cnuc, municipios_tis) # Juntando os nomes
municipios = list(municipios)
for i in range(len(municipios)):
    municipios[i] = municipios[i].strip() # Alguns nomes estavam com um espaço no início ou no final

municipios
# Out:
# ['santa maria das barreiras',
#  'ourilandia do norte',
#  'barcarena',
#  'oriximina',
#  'gurupa',
#  'melgaco',
#  'altamira',
#  'afua',
#  'oriximina',
#  'floresta do araguaia',
#  'abaetetuba',
#  'tucurui',
#  'tome-acu',
#  'porto de moz',
#  'baiao',
#  'capitao poco',
#  'cachoeira do arari',
#  'capanema',
#  'aurora do para',
#  'santa cruz do arari',
#  'portel',
#  'tucurui',
#  'cameta',
#  'altamira',
#  'novo repartimento',
#  'benevides',
#  'santa luzia do para',
#  'breves',
#  'ananindeua',
#  'nova ipixuna',
#  'canaa dos carajas',
#  'senador jose porfirio',
#  'canaa dos carajas',
#  'abaeteuba',
#  'alenquer',
#  'juruti',
#  'gurupa',
#  'sao joao de pirabas',
#  'curralinho',
#  'viseu',
#  'redencao',
#  'ipixuna do para',
#  'primavera',
#  'oeiras do para',
#  'santo antonio do taua',
#  'rondon do para',
#  'santa isabel do para',
#  'cameta e mocajuba',
#  'aveiro',
#  'sao miguel do guama',
#  'breu branco',
#  'baiao',
#  'ourem',
#  'paragominas',
#  'salvaterra',
#  'anajas',
#  'placas',
#  'sao joao da ponta',
#  'santarem novo',
#  'braganca',
#  'prainha',
#  'vitoria do xingu',
#  'nova esperanca do piria',
#  'tracuateua',
#  'sao geraldo do araguaia',
#  'augusto correa',
#  'cachoeira do piria',
#  'mocajuba',
#  'sao felix do xingu',
#  "pau d'arco",
#  'laranjal do jari (ap), mazagao (ap)',
#  'parauapebas',
#  'jacareacanga',
#  'ruropolis',
#  'moju',
#  'maraba',
#  'marapanim',
#  'cameta',
#  'maues (am)',
#  'jacareacanga',
#  'sao felix do xingu',
#  'obidos',
#  'santa izabel do para',
#  'acara',
#  'brasil novo',
#  'bannach',
#  'maracana',
#  'agua azul do norte',
#  'goianesia do para',
#  'belterra',
#  'uruara',
#  'santa izabel do para',
#  'terra santa',
#  'parauapebas',
#  'irituia',
#  'trairao',
#  'marituba',
#  'ruropolis',
#  'santa izabel',
#  'tracuateua',
#  'belem',
#  'itupiranga',
#  'sao domingos do capim',
#  'bujaru',
#  'calcoene (ap), laranjal do jari (ap), oiapoque (ap), serra do navio (ap)',
#  'oeiras do para',
#  'soure',
#  'monte alegre',
#  'redencao',
#  'senador jose porfirio',
#  'faro',
#  'sao sebastiao da boa vista',
#  'salinopolis',
#  'curuca',
#  'cahoeira do piria',
#  'castanhal',
#  'quatipuru',
#  'itaituba',
#  'medicilandia',
#  'trairao',
#  'anapu',
#  'bagre',
#  'maraba',
#  'sao caetano de odivelas',
#  'monte alegre',
#  'castanhal',
#  'viseu',
#  'chaves',
#  'cumaru do norte',
#  'obidos',
#  'maraba',
#  'santarem',
#  'melgaco',
#  'bom jesus do tocantins',
#  'jacunda',
#  'santarem',
#  'magalhaes barata',
#  'braganca',
#  'sao geraldo do araguaia',
#  'garrafao do norte',
#  'sao domingos do araguaia',
#  'sao joao de pirabas',
#  'inhangapi',
#  'concordia do para',
#  'muana',
#  'novo progresso',
#  'afua',
#  'igarape-acu',
#  'novo progresso',
#  'ananindeua',
#  'almeirim',
#  'colares',
#  'salinopolis',
#  'sao sebastiao da boa vista']

# %%
sigef_f_mun = sigef_f[sigef_f["municipio"].isin(municipios)] # Filtrando base
sigef_f_mun.sample(5)
# Out:
#                                          cod_imovel ind_tipo  \
# 217144  PA-1505205-1FAA4808132C4C5AA27EFE063CE58122      IRU
# 214063  PA-1505437-D9957395AD6D416CA9815B6839AB7164      IRU
# 311467  PA-1506187-C19C99AF19E6498384B2D53BBA5F0D9B      IRU
# 169365  PA-1500909-1DB2FCC7DC924D01B190F9C962532220      IRU
# 318263  PA-1505650-1D7D6232FA364305A93C7AD65E3C59AA      IRU
#
#                   municipio  num_area  \
# 217144       oeiras do para   18.4347
# 214063  ourilandia do norte   97.1727
# 311467       rondon do para   38.8409
# 169365       augusto correa   28.3613
# 318263               placas   99.6169
#
#                                                  geometry
# 217144  POLYGON ((-49.92203 -1.91218, -49.91931 -1.913...
# 214063  POLYGON ((-50.9297 -6.89572, -50.92984 -6.8968...
# 311467  POLYGON ((-48.37572 -4.88381, -48.36581 -4.878...
# 169365  POLYGON ((-46.59368 -1.18694, -46.58728 -1.195...
# 318263  POLYGON ((-54.77286 -4.06808, -54.76905 -4.085...

# %%
alertas_f_mun = alertas_f[alertas_f["MUNICIPIO"].isin(municipios)] # Filtrando base
alertas_f_mun.sample(5)
# Out:
#        CODEALERTA                       FONTE     BIOMA ESTADO  \
# 41484        4242  {DETERB-AMAZONIA,GLAD,SAD}  Amazônia   PARÁ
# 47512       48912                  {GLAD,SAD}  Amazônia   PARÁ
# 89825      950931                    {SIRADX}  Amazônia   PARÁ
# 29264      224259                       {SAD}  Amazônia   PARÁ
# 76075      340813                       {SAD}  Amazônia   PARÁ
#
#                 MUNICIPIO  AREAHA  ANODETEC  DATADETEC   DTIMGANT   DTIMGDEP  \
# 41484               anapu    8.16    2019.0 2019-06-01 2018-10-01 2019-06-23
# 47512               anapu   22.02    2019.0 2019-09-01 2019-08-19 2019-09-24
# 89825            itaituba    0.07    2023.0 2023-06-01 2022-12-10 2023-06-26
# 29264  sao felix do xingu   16.13    2020.0 2020-09-01 2020-06-28 2020-09-29
# 76075              maraba    6.68    2021.0 2021-05-01 2021-04-08 2021-06-30
#
#          DTPUBLI     VPRESSAO  \
# 41484 2020-02-11  agriculture
# 47512 2020-02-11  agriculture
# 89825 2023-09-04       mining
# 29264 2020-10-22  agriculture
# 76075 2021-06-16  agriculture
#
#                                                 geometry
# 41484  POLYGON ((-51.59915 -3.47168, -51.59888 -3.471...
# 47512  POLYGON ((-51.44938 -3.57083, -51.44909 -3.570...
# 89825  POLYGON ((-55.34314 -6.03526, -55.34312 -6.035...
# 29264  MULTIPOLYGON (((-52.21367 -5.82072, -52.21338 ...
# 76075  POLYGON ((-50.5155 -5.81053, -50.51529 -5.8107...

# %%
alertas_f_mun.to_file("areas-PA/area-alertas-filtrado/alertas_pa_filtrado.shp")
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Field DATADETEC create as date field, though DateTime requested.
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Field DTIMGANT create as date field, though DateTime requested.
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Field DTIMGDEP create as date field, though DateTime requested.
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Field DTPUBLI create as date field, though DateTime requested.
#   ogr_write(

# %%
sigef_f_mun.to_file("areas-PA/area-imovel-filtrado/sigef_pa_filtrado.shp") # Salvando em um arquivo separado

# %% [markdown]
# # 3. Calculando interseções

# %%
# Calculando a área de interseção entre as geometrias
from pyproj import Geod

def calculate_area_count(df1, df2, sep, column1, column2):
    geod = Geod(ellps="WGS84")
    areas, counts = [], []
    for i, row in df1.iterrows(): # iterando na base
        sum, count= 0, 0 # Criando a variável para somar as áreas
        aux = row[column1].split(sep) # Separando os municípios que estão em uma mesma linha, nem todas as linhas tem mais de um município
        muns = set() # Armazenando em um conjunto porque não queremos municípios repetidos
        for k in aux: # Iterando na lista, podendo ser uma lista de apenas um município
            muns.add(k.strip()) # Removendo espaços, e colocando ele no conjunto
        
        for j, row_j in df2[df2[column2].isin(muns)].iterrows(): # iterando na base, e filtrando apenas com os municípios que estão na linha da iteração quilombola
            geod_area = abs(geod.geometry_area_perimeter(row["geometry"].intersection(row_j["geometry"]))[0]) # Calculando a área de interseção entre as geometrias, e somando a área
            if geod_area > 0: # Se a área for maior que 0, então a interseção é válida
                count += 1
                sum += geod_area
        areas.append(float(f"{round(sum, 2):.2f}")) # Salvando a soma das áreas
        counts.append(count)

    return areas, counts

# %% [markdown]
# ## 3.1 Quilombola

# %%
# SIGEF
areas_quilombola_sigef, count_quilombola_sigef = calculate_area_count(quilombola_f, sigef_f_mun, ' / ', 'nm_municip', 'municipio')

print(areas_quilombola_sigef[:5])
print(count_quilombola_sigef[:5])
# Out:
# [14888.71, 291703.89, 3325326.72, 306583.27, 13172029.6]
# [1, 5, 2, 3, 4]

# %%
# ALERTAS

areas_quilombola_alertas, count_quilombola_alertas = calculate_area_count(quilombola_f, alertas_f_mun, ' / ', 'nm_municip', 'MUNICIPIO')

print(areas_quilombola_alertas[:5])
print(count_quilombola_alertas[:5])
# Out:
# [4903.9, 0.0, 10801261.34, 0.0, 0.0]
# [1, 0, 41, 0, 0]

# %% [markdown]
# ## 3.2 CNUC

# %%
# SIGEF
areas_cnuc_sigef, count_cnuc_sigef = calculate_area_count(cnuc_f, sigef_f_mun, ' , ', 'municipio', 'municipio')

print(areas_cnuc_sigef[:5])
print(count_cnuc_sigef[:5])
# Out:
# [291862249.66, 119168537.73, 1355761493.05, 0.0, 570324947.07]
# [46, 89, 60, 0, 43]

# %%
# Alertas
areas_cnuc_alertas, count_cnuc_alertas = calculate_area_count(cnuc_f, alertas_f_mun, ' , ', 'municipio', 'MUNICIPIO')

print(areas_cnuc_alertas[:5])
print(count_cnuc_alertas[:5])
# Out:
# [41331871.03, 4841691.67, 5655743.9, 0.0, 12706.16]
# [157, 107, 94, 0, 1]

# %% [markdown]
# ## 3.3 TIS

# %%
# SIGEF 
areas_tis_sigef, count_tis_sigef = calculate_area_count(tis_f, sigef_f_mun, ',', 'municipio', 'municipio')

print(areas_tis_sigef[:5])
print(count_tis_sigef[:5])
# Out:
# [19576561.45, 1585609956.61, 5823997.3, 281427234.01, 2945436.62]
# [85, 73, 8, 79, 85]

# %%
# Alertas
areas_tis_alertas, count_tis_alertas = calculate_area_count(tis_f, alertas_f_mun, ',', 'municipio', 'MUNICIPIO')

print(areas_tis_alertas[:5])
print(count_tis_alertas[:5])
# Out:
# [10240006.49, 4941552.22, 433733.16, 381881328.84, 738643.34]
# [201, 18, 17, 2546, 54]

# %% [markdown]
# ## 3.4 Agregando as informações aos dataframes

# %%
# Quilombola
quilombola_f["a_sigef"] = areas_quilombola_sigef
quilombola_f["c_sigef"] = count_quilombola_sigef
quilombola_f["a_alertas"] = areas_quilombola_alertas
quilombola_f["c_alertas"] = count_quilombola_alertas

quilombola_f = quilombola_f[["nm_comunid", 'nm_municip', 'nr_familia', 'nr_area_ha', 'a_sigef', 'c_sigef', 'a_alertas', 'c_alertas', 'geometry']]

# CNUC
cnuc_f["a_sigef"] = areas_cnuc_sigef
cnuc_f["c_sigef"] = count_cnuc_sigef
cnuc_f["a_alertas"] = areas_cnuc_alertas
cnuc_f["c_alertas"] = count_cnuc_alertas

cnuc_f = cnuc_f[['nome_uc', 'ha_total', 'uf', 'municipio', 'situacao', 'a_sigef', 'c_sigef', 'a_alertas', 'c_alertas', 'geometry']]

#TIS
tis_f["a_sigef"] = areas_tis_sigef
tis_f["c_sigef"] = count_tis_sigef
tis_f["a_alertas"] = areas_tis_alertas
tis_f["c_alertas"] = count_tis_alertas

tis_f = tis_f[['etnia_nome', 'municipio', 'a_sigef', 'c_sigef', 'a_alertas', 'c_alertas', 'geometry']]

# %% [markdown]
# # 4. Salvando resultados

# %%
quilombola_f.to_file("areas-PA/areas-de-interesse/quilombola/quilombola_pa_dados.shp")
cnuc_f.to_file("areas-PA/areas-de-interesse/cnuc/cnuc_pa_dados.shp")
tis_f.to_file("areas-PA/areas-de-interesse/tis/tis_pa_dados.shp")
# Out:
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 134908527.599999994 of field a_sigef of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 809753458.710000038 of field a_sigef of feature 36 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 497374719.920000017 of field a_sigef of feature 43 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 177763792.639999986 of field a_sigef of feature 58 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 297495438.350000024 of field a_sigef of feature 62 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 140976415.969999999 of field a_sigef of feature 63 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 175071820 of field a_sigef of feature 80 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 291862249.660000026 of field a_sigef of feature 0 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 119168537.730000004 of field a_sigef of feature 1 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1355761493.04999995 of field a_sigef of feature 2 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 570324947.070000052 of field a_sigef of feature 4 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1458025694.1099999 of field a_sigef of feature 5 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1452249151.04999995 of field a_sigef of feature 13 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 664082030.00999999 of field a_sigef of feature 14 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 227259670.599999994 of field a_sigef of feature 15 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 7264551137.43000031 of field a_sigef of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 496794175.899999976 of field a_alertas of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1456243886.45000005 of field a_sigef of feature 17 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 14844928463.3799992 of field a_sigef of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 369630672.74000001 of field a_alertas of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 3751217933.42999983 of field a_sigef of feature 19 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 871770646.320000052 of field a_sigef of feature 20 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 4281110031.67000008 of field a_sigef of feature 22 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 48716078168.5500031 of field a_sigef of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 222278614.960000008 of field a_sigef of feature 28 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 434389343.379999995 of field a_sigef of feature 30 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 3122631966.30999994 of field a_sigef of feature 31 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 138142536.460000008 of field a_sigef of feature 33 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 215217712.449999988 of field a_sigef of feature 35 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 4726090635.43999958 of field a_sigef of feature 38 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2165606424.80000019 of field a_sigef of feature 39 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 29611135316.7200012 of field a_sigef of feature 40 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 23004908673.7000008 of field a_sigef of feature 41 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1810394947.71000004 of field a_alertas of feature 41 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2494281473.61000013 of field a_sigef of feature 42 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 367417489.699999988 of field a_sigef of feature 43 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1364921408.44000006 of field a_sigef of feature 46 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 156943547.800000012 of field a_sigef of feature 57 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 133968734.810000002 of field a_sigef of feature 73 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 379169202.420000017 of field a_sigef of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 145385837.789999992 of field a_alertas of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 506417824.730000019 of field a_sigef of feature 75 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1077202479.1400001 of field a_sigef of feature 77 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 3328687154.69000006 of field a_sigef of feature 81 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 266329282.909999996 of field a_sigef of feature 82 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 477074784.660000026 of field a_sigef of feature 83 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 284056738.49000001 of field a_sigef of feature 84 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 117348004.590000004 of field a_sigef of feature 86 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 147139055.849999994 of field a_sigef of feature 87 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 210434392.560000002 of field a_sigef of feature 89 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 943301728.309999943 of field a_sigef of feature 92 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 582292998.690000057 of field a_sigef of feature 93 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 25851858773.3600006 of field a_sigef of feature 94 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 117797232.310000002 of field a_alertas of feature 94 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1585609956.6099999 of field a_sigef of feature 1 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 281427234.00999999 of field a_sigef of feature 3 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 381881328.839999974 of field a_alertas of feature 3 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 1526750223.52999997 of field a_sigef of feature 11 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 179893951.810000002 of field a_alertas of feature 11 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 246923478.689999998 of field a_sigef of feature 12 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 2094071619.00999999 of field a_sigef of feature 15 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 112906756.840000004 of field a_alertas of feature 15 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 118834024.629999995 of field a_sigef of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 609830554.029999971 of field a_sigef of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 878138375.230000019 of field a_sigef of feature 26 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 166913811.020000011 of field a_sigef of feature 38 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 273642163.970000029 of field a_sigef of feature 39 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 115131943.799999997 of field a_alertas of feature 42 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /home/toledo-cia/anaconda3/lib/python3.12/site-packages/pyogrio/raw.py:709: RuntimeWarning: Value 219001950.939999998 of field a_sigef of feature 47 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
